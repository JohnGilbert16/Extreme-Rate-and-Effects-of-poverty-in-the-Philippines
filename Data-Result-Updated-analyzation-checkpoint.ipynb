# %%
import pandas as pd
import numpy as nd
import matplotlib
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.style.use("bmh")
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\lenovo ideapad 110\Documents\Python Scripts\consolidated_philippines_poverty_data.csv')
df.head()
# Out:
#           regDesc  agr_wage_farm_workers_allgender_2015  \
# 0            Armm                                162.89
# 1    Bicol Region                                167.99
# 2  Cagayan Valley                                228.77
# 3      Calabarzon                                230.92
# 4             Car                                206.68
#
#    agr_wage_farm_workers_male_2015  agr_wage_farm_workers_female_2015  \
# 0                           163.65                             103.81
# 1                           169.95                             119.52
# 2                           232.64                             199.98
# 3                           231.45                             172.04
# 4                           211.04                             195.62
#
#    avg_annual_total_incm_farm_households_02_03  \
# 0                                        73356
# 1                                        82988
# 2                                       145809
# ...

# %%
region = df['regDesc']
region
# Out:
# 0                    Armm
# 1            Bicol Region
# 2          Cagayan Valley
# 3              Calabarzon
# 4                     Car
# 5                  Caraga
# 6           Central Luzon
# 7         Central Visayas
# 8            Davao Region
# 9         Eastern Visayas
# 10          Ilocos Region
# 11               Mimaropa
# 12      Northern Mindanao
# 13           Soccsksargen
# 14        Western Visayas
# 15    Zamboanga Peninsula
# Name: regDesc, dtype: object

# %%
male = df['agr_wage_farm_workers_male_2015']
male
# Out:
# 0     163.65
# 1     169.95
# 2     232.64
# 3     231.45
# 4     211.04
# 5     195.44
# 6     259.04
# 7     160.65
# 8     169.83
# 9     159.25
# 10    239.19
# 11    192.16
# 12    160.07
# 13    166.75
# 14    167.77
# 15    158.55
# Name: agr_wage_farm_workers_male_2015, dtype: float64

# %%
female = df['agr_wage_farm_workers_female_2015']
female
# Out:
# 0     103.81
# 1     119.52
# 2     199.98
# 3     172.04
# 4     195.62
# 5     187.78
# 6     204.73
# 7     150.67
# 8     158.91
# 9     112.22
# 10    199.04
# 11    170.73
# 12    151.39
# 13    159.14
# 14    156.96
# 15    152.79
# Name: agr_wage_farm_workers_female_2015, dtype: float64

# %%
y= df.agr_wage_farm_workers_female_2015
plt.figure(figsize=(10,10))

plt.plot(z, c ='yellow', label = 'Female Worker')
plt.legend()
plt.ylabel('Female Workers')
plt.xlabel('Regions')
plt.title("Ploting Female working in a Farm", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Ploting Female working in a Farm')

# %%
x = df.agr_wage_farm_workers_male_2015	
plt.figure(figsize=(10,10))

plt.plot(z, c ='Green', label = 'Male Worker')
plt.legend()
plt.ylabel('Male Workers')
plt.xlabel('Regions')
plt.title("Ploting Male working in a Farm", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Ploting Male working in a Farm')

# %%
x=df.agr_wage_farm_workers_male_2015
y= df.agr_wage_farm_workers_female_2015
plt.figure(figsize=(10,10))

plt.plot(x, c ='yellow', label = 'Male Worker')
plt.plot(y, c='Green', label='Female worker')
plt.legend()
plt.ylabel('Female Workers')
plt.xlabel('Male Worker')
plt.title("Ploting Female working in a Farm", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Ploting Female working in a Farm')

# %%
farming = df['avg_annual_farm_incm_farm_households_02_03']
farming
# Out:
# 0     34026
# 1     36579
# 2     87353
# 3     64498
# 4     71142
# 5     54004
# 6     85048
# 7     28074
# 8     69496
# 9     47359
# 10    51544
# 11    74702
# 12    49988
# 13    84331
# 14    41266
# 15    54135
# Name: avg_annual_farm_incm_farm_households_02_03, dtype: int64

# %%
farming = df['avg_annual_off_farm_incm_farm_households_02_03']
farming
# Out:
# 0      5737
# 1      7348
# 2      6909
# 3      8444
# 4      9731
# 5     11118
# 6      6073
# 7      5574
# 8      5593
# 9      6066
# 10     4358
# 11     6579
# 12     4256
# 13     9347
# 14     6746
# 15     5946
# Name: avg_annual_off_farm_incm_farm_households_02_03, dtype: int64

# %%
farming = df['avg_annual_non_farm_incm_farm_households_02_03']
farming
# Out:
# 0     24936
# 1     30381
# 2     39894
# 3     48590
# 4     37178
# 5     13892
# 6     50413
# 7     31055
# 8     17573
# 9     23812
# 10    36054
# 11    35262
# 12    23279
# 13    33658
# 14    21772
# 15    33431
# Name: avg_annual_non_farm_incm_farm_households_02_03, dtype: int64

# %%
farming = df['avg_annual_other_sources_incm_farm_households_02_03']
farming
# Out:
# 0      8657
# 1      8680
# 2     11653
# 3     21543
# 4      9016
# 5      5555
# 6     16596
# 7      7474
# 8      9011
# 9      5266
# 10    26681
# 11     9694
# 12     4776
# 13     7070
# 14    10165
# 15     5815
# Name: avg_annual_other_sources_incm_farm_households_02_03, dtype: int64

# %%
sns.barplot(x="avg_annual_farm_incm_farm_households_02_03", y="regDesc",data=df)

# %%
sns.barplot(x="avg_annual_non_farm_incm_farm_households_02_03", y="regDesc",data=df)
# Out:
# <AxesSubplot:xlabel='avg_annual_non_farm_incm_farm_households_02_03', ylabel='regDesc'>

# %%
sns.barplot(x="avg_annual_other_sources_incm_farm_households_02_03", y="regDesc",data=df)
# Out:
# <AxesSubplot:xlabel='avg_annual_other_sources_incm_farm_households_02_03', ylabel='regDesc'>
