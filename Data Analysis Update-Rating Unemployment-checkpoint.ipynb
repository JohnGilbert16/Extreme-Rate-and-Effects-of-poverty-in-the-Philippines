# %%
import pandas as pd
import numpy as nd
import matplotlib
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.style.use("bmh")
import seaborn as sns

# %%
df = pd.read_csv('Family_size-Sheet1.csv')
df.head()
# Out:
#    Family size  Incidence _Y  Incidence_M  Incidence_X  Distribution_Z  \
# 0  Less than 3           9.0          7.7          8.2             0.3
# 1   3-4 member          15.1         15.6         15.2            10.1
# 2  5-6 members          29.1         31.9         32.9            34.3
# 3           7+          48.0         50.2         51.5            55.3
#
#    Distribution_R  Distribution_V
# 0             0.3             0.3
# 1             9.3             9.3
# 2            35.6            37.2
# 3            54.8            53.2

# %%
Family = df['Family size']
Family
# Out:
# 0    Less than 3
# 1     3-4 member
# 2    5-6 members
# 3             7+
# Name: Family size, dtype: object

# %%
Incidence_y = df['Incidence _Y']
Incidence_y
# Out:
# 0     9.0
# 1    15.1
# 2    29.1
# 3    48.0
# Name: Incidence _Y, dtype: float64

# %%
Incidence_m = df['Incidence_M']
Incidence_m
# Out:
# 0     7.7
# 1    15.6
# 2    31.9
# 3    50.2
# Name: Incidence_M, dtype: float64

# %%
Incidence_x = df['Incidence_X']
Incidence_x
# Out:
# 0     8.2
# 1    15.2
# 2    32.9
# 3    51.5
# Name: Incidence_X, dtype: float64

# %%
Distribution_z = df['Distribution_Z']
Distribution_z
# Out:
# 0     0.3
# 1    10.1
# 2    34.3
# 3    55.3
# Name: Distribution_Z, dtype: float64

# %%
Distribution_r = df['Distribution_R']
Distribution_r
# Out:
# 0     0.3
# 1     9.3
# 2    35.6
# 3    54.8
# Name: Distribution_R, dtype: float64

# %%
Distribution_v = df['Distribution_V']
Distribution_v
# Out:
# 0     0.3
# 1     9.3
# 2    37.2
# 3    53.2
# Name: Distribution_V, dtype: float64

# %%
sns.barplot(x="Incidence _Y", y="Family size",data=df)
plt.xlabel("Incidence 2003")
plt.title("Family Size Incidence 2003", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Family Size Incidence 2003')

# %%
sns.barplot(x="Incidence_M", y="Family size",data=df)
plt.xlabel("Incidence 2006")
plt.title("Family Size Incidence 2006", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Family Size Incidence 2006')

# %%
sns.barplot(x="Incidence_X", y="Family size",data=df)
plt.xlabel("Incidence 2009")
plt.title("Family Size Incidence 2009", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Family Size Incidence 2009')

# %%
sns.barplot(x="Distribution_Z", y="Family size",data=df)
plt.xlabel("Incidence 2003")
plt.title("Family Size Distribution 2003", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Family Size Distribution 2003')

# %%
sns.barplot(x="Distribution_R", y="Family size",data=df)
plt.xlabel("Incidence 2006")
plt.title("Family Size Distribution 2006", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Family Size Distribution 2006')

# %%
sns.barplot(x="Distribution_V", y="Family size",data=df)
plt.xlabel("Incidence 2009")
plt.title("Family Size Distribution 2009", fontweight ="bold")

# %%
df = pd.read_csv('Geographic-Sheet1.csv')
df.head()
# Out:
#   Geographic_dimension  Incidence_A  Incidence_B  Incidence_C  Distribution_D  \
# 0                  NCR          4.9          8.1          6.7             1.7
# 1                  CAR         27.3         31.8         30.4             1.6
# 2      I-Ilocos Region         30.7         35.4         31.0             4.8
# 3   II- Cagayan Valley         26.1         26.5         25.5             2.8
# 4   III- Central Luzon         17.2         20.7         21.2             5.1
#
#    Distribution_L  Distribution_Q
# 0             2.9             2.0
# 1             1.7             1.5
# 2             6.0             4.5
# 3             3.0             2.5
# 4             6.6             6.0

# %%
sns.barplot(x="Incidence_A", y="Geographic_dimension",data=df)
plt.xlabel("Incidence 2003", fontweight ="bold")
plt.ylabel("Geographic", fontweight ="bold")
plt.title("Geographic Incidence 2003", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Geographic Incidence 2003')

# %%
sns.barplot(x="Incidence_B", y="Geographic_dimension",data=df)
plt.xlabel("Incidence 2006", fontweight ="bold")
plt.ylabel("Geographic", fontweight ="bold")
plt.title("Geographic Incidence 2006", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Geographic Incidence 2006')

# %%
sns.barplot(x="Incidence_C", y="Geographic_dimension",data=df)
plt.xlabel("Incidence 2009", fontweight ="bold")
plt.ylabel("Geographic", fontweight ="bold")
plt.title("Geographic Incidence 2009", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Geographic Incidence 2009')

# %%
sns.barplot(x="Distribution_D", y="Geographic_dimension",data=df)
plt.xlabel("Distribution 2003", fontweight ="bold")
plt.ylabel("Geographic", fontweight ="bold")
plt.title("Geographic Distribution 2003", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Geographic Distribution 2003')

# %%
sns.barplot(x="Distribution_L", y="Geographic_dimension",data=df)
plt.xlabel("Distribution 2006", fontweight ="bold")
plt.ylabel("Geographic", fontweight ="bold")
plt.title("Geographic Distribution 2006", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Geographic Distribution 2006')

# %%
sns.barplot(x="Distribution_Q", y="Geographic_dimension",data=df)
plt.xlabel("Distribution 2009", fontweight ="bold")
plt.ylabel("Geographic", fontweight ="bold")
plt.title("Geographic Distribution 2009", fontweight ="bold")
# Out:
# Text(0.5, 1.0, 'Geographic Distribution 2009')
